# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Machine Learning/diamonds.csv')
df.shape
# Out:
# (53940, 10)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.duplicated().sum()
# Out:
# np.int64(146)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53794 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53794 non-null  float64
#  1   cut      53794 non-null  object
#  2   color    53794 non-null  object
#  3   clarity  53794 non-null  object
#  4   depth    53794 non-null  float64
#  5   table    53794 non-null  float64
#  6   price    53794 non-null  int64
#  7   x        53794 non-null  float64
#  8   y        53794 non-null  float64
#  9   z        53794 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.5+ MB

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        21488
# Premium      13748
# Very Good    12069
# Good          4891
# Fair          1598
# Name: count, dtype: int64

# %%
df.color.value_counts()
# Out:
# color
# G    11262
# E     9776
# F     9520
# H     8272
# D     6755
# I     5407
# J     2802
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     13032
# VS2     12229
# SI2      9150
# VS1      8156
# VVS2     5056
# VVS1     3647
# IF       1784
# I1        740
# Name: count, dtype: int64

# %% [markdown]
# ## Step - 3: Split the data - Test and Train (recommended 75:25 split)

# %%
X= df.drop('price',axis=1)
Y= df['price']
X.shape,Y.shape
# Out:
# ((53794, 9), (53794,))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test= train_test_split(X,Y, test_size= 0.25, random_state= 42)
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((40345, 9), (13449, 9), (40345,), (13449,))

# %% [markdown]
# ## Step - 4: Data Preprocessing on X_train

# %%
df.clarity.unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
df.color.unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
df.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
#For Ordinal Encoding Categories Order
#cut
cut_order= [ 'Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
#color
color_order= [ 'D', 'E', 'F', 'G', 'H', 'I', 'J']
#clarity
clarity_order= [ 'I1', 'SI1', 'SI2', 'VS1', 'VS2', 'VVS1', 'VVS2', 'IF']

# %%
from sklearn.preprocessing import OrdinalEncoder
oe= OrdinalEncoder(categories=[cut_order,color_order,clarity_order]).set_output(transform='pandas')
oe
# Out:
# OrdinalEncoder(categories=[['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],
#                            ['D', 'E', 'F', 'G', 'H', 'I', 'J'],
#                            ['I1', 'SI1', 'SI2', 'VS1', 'VS2', 'VVS1', 'VVS2',
#                             'IF']])

# %%
from sklearn.preprocessing import MinMaxScaler
mms= MinMaxScaler().set_output(transform='pandas')
mms
# Out:
# MinMaxScaler()

# %%
from sklearn.compose import ColumnTransformer
ct= ColumnTransformer([('Ordinal Encoding',oe, ['cut','color','clarity']),
                      ('Scaling', mms, ['carat',	'depth', 'table',	'x',	'y',	'z'])],
                      remainder='passthrough',verbose_feature_names_out=False).set_output(transform='pandas')
ct
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('Ordinal Encoding',
#                                  OrdinalEncoder(categories=[['Fair', 'Good',
#                                                              'Very Good',
#                                                              'Premium',
#                                                              'Ideal'],
#                                                             ['D', 'E', 'F', 'G',
#                                                              'H', 'I', 'J'],
#                                                             ['I1', 'SI1', 'SI2',
#                                                              'VS1', 'VS2',
#                                                              'VVS1', 'VVS2',
#                                                              'IF']]),
#                                  ['cut', 'color', 'clarity']),
#                                 ('Scaling', MinMaxScaler(),
#                                  ['carat', 'depth', 'table', 'x', 'y', 'z'])],
#                   verbose_feature_names_out=False)

# %%
x_train_transformed= ct.fit_transform(X_train)
x_train_transformed
# Out:
#        cut  color  clarity     carat     depth     table         x         y  \
# 12820  4.0    3.0      4.0  0.170478  0.538889  0.269231  0.602421  0.107980
# 19997  2.0    2.0      6.0  0.176715  0.508333  0.307692  0.603352  0.111375
# 6099   3.0    3.0      1.0  0.147609  0.544444  0.288462  0.574488  0.104244
# 37984  4.0    0.0      6.0  0.024948  0.497222  0.269231  0.408752  0.075552
# 24865  3.0    3.0      4.0  0.274428  0.525000  0.250000  0.688082  0.123599
# ...    ...    ...      ...       ...       ...       ...       ...       ...
# 11311  3.0    4.0      4.0  0.166320  0.483333  0.288462  0.606145  0.109677
# 44869  4.0    3.0      1.0  0.089397  0.519444  0.211538  0.513966  0.094397
# 38271  4.0    6.0      1.0  0.024948  0.522222  0.228846  0.408752  0.075042
# 860    3.0    6.0      1.0  0.145530  0.550000  0.307692  0.570764  0.102377
# 15832  3.0    3.0      3.0  0.168399  0.547222  0.288462  0.592179  0.107131
#
#               z
# 12820  0.496278
# 19997  0.496278
# 6099   0.477667
# 37984  0.334988
# 24865  0.563275
# ...         ...
# 11311  0.486352
# 44869  0.424318
# 38271  0.337469
# 860    0.473945
# 15832  0.492556
#
# [40345 rows x 9 columns]

# %% [markdown]
# ## Step - 5: Data Preprocessing on X_test

# %%
x_test_transformed= ct.transform(X_test)
x_test_transformed
# Out:
#        cut  color  clarity     carat     depth     table         x         y  \
# 43657  0.0    6.0      4.0  0.106029  0.608333  0.211538  0.524209  0.093888
# 4274   2.0    1.0      2.0  0.145530  0.500000  0.307692  0.571695  0.104924
# 47412  4.0    3.0      3.0  0.076923  0.530556  0.250000  0.493482  0.090492
# 44437  3.0    1.0      4.0  0.064449  0.541667  0.326923  0.472998  0.086587
# 13975  4.0    5.0      1.0  0.205821  0.536111  0.230769  0.633147  0.115789
# ...    ...    ...      ...       ...       ...       ...       ...       ...
# 43980  2.0    4.0      2.0  0.024948  0.483333  0.307692  0.408752  0.075042
# 1115   2.0    4.0      3.0  0.110187  0.494444  0.269231  0.540037  0.098981
# 48829  4.0    3.0      5.0  0.066528  0.527778  0.230769  0.479516  0.087946
# 42876  0.0    1.0      1.0  0.074844  0.597222  0.346154  0.486034  0.086418
# 52752  3.0    2.0      4.0  0.112266  0.536111  0.288462  0.537244  0.097114
#
#               z
# 43657  0.449132
# 4274   0.466501
# 47412  0.409429
# 44437  0.394541
# 13975  0.526055
# ...         ...
# 43980  0.330025
# 1115   0.439206
# 48829  0.397022
# 42876  0.413151
# 52752  0.444169
#
# [13449 rows x 9 columns]

# %% [markdown]
# ## Step - 6: Build the model and predict on X_test (SCRATCH IMPLEMENTATION)
# Implement KNN Algorithm from scratch and do the predictions for test data. You should not use the sklearn KNN algorithm here. Write the complete code implementation from scratch for KNN algorithm.

# %%
def manual_knn(x_train,y_train,x_test,k):
  y_pred= []
  for x in x_test.values:
    dist= np.sqrt(np.sum((x_train-x)**2,axis=1))
    sorted_dist= dist.argsort()[:k]
    y_pred.append(y_train.iloc[sorted_dist].mean())
  return np.array(y_pred)

# %%
y_pred= manual_knn(x_train_transformed,Y_train,x_test_transformed,5)
y_pred
# Out:
# array([2567.4, 3777.6, 1786.8, ..., 2017. , 1376.4, 2814.4])

# %% [markdown]
# ## Step - 7: Evaluate your model

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,y_pred)
# Out:
# 0.957424235511545

# %% [markdown]
# ## Step - 8: Train a model using sklearn KNN Algorithm and compare the results with your scratch implementation

# %%
from sklearn.neighbors import KNeighborsRegressor
knn= KNeighborsRegressor(n_neighbors=5)
knn
# Out:
# KNeighborsRegressor()

# %%
knn.fit(x_train_transformed,Y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.score(x_train_transformed,Y_train)
# Out:
# 0.975925007978189

# %%
y_pred= knn.predict(x_test_transformed)
y_pred
# Out:
# array([2567.4, 3777.6, 1786.8, ..., 2017. , 1376.4, 2814.4])

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.957424235511545

# %% [markdown]
# For both manual implementation and scikit-learn knn algorithm, I got same performance score 95%.
